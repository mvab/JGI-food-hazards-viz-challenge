# %% [markdown]
# Notes:
#
# - Try plotting with other alert_type filter than just 'recall'
# - May need to try and standardise recall counts by amount of food produced by that country
#     - Could even try and break that down further, look at how much of each class of food a country produces.

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
food_haz = pd.read_csv('../data/tidy/food_hazards_data_all.csv')
food_haz.head()
# Out:
#        ID  ID_incident date_published  \
# 0  218195       218195     2020-05-20
# 1  218196       218196     2020-05-20
# 2  218198       218198     2020-05-20
# 3  218199       218199     2020-05-20
# 4  218201       218201     2020-05-20
#
#                                data_source source_type alert_type  \
# 0                  AFSCA Recalls (Belgium)    Official    warning
# 1             Food Poisoning Bulletin (US)      Others   outbreak
# 2  Product Recalls Website: Oulah (France)      Others     recall
# 3  Product Recalls Website: Oulah (France)      Others     recall
# 4  Product Recalls Website: Oulah (France)      Others     recall
#
#                                     raw_text_product  \
# 0  Allergens not listed on the label are almonds ...
# 1  Backyard Poultry Salmonella Outbreak Sickens 9...
# 2  Recall product : Terrine of guinea Fowl with g...
# 3  Recall product : Chiffonnade of ham cooked abo...
# 4      Recall product : peas & carrots brand DANIVAL
#
#                               product_categoty  product  \
# 0                 nuts; nut products and seeds   almond
# 1       poultry meat and poultry meat products  chicken
# 2                        fruits and vegetables   pepper
# 3  meat and meat products (other than poultry)     pork
# 4                        fruits and vegetables      pea
#
#              origin_country  ... date_published_quarter  \
# 0                   Belgium  ...                     Q2
# 1  United States of America  ...                     Q2
# 2                    France  ...                     Q2
# 3                    France  ...                     Q2
# 4                    France  ...                     Q2
#
#   date_published_year_quarter long.origin lat.origin long.notified  \
# 0                     2020-Q2    4.640646  50.639814      4.640646
# 1                     2020-Q2 -112.461671  45.679552   -112.461671
# 2                     2020-Q2    2.536185  46.187006      2.536185
# 3                     2020-Q2    2.536185  46.187006      2.536185
# 4                     2020-Q2    2.536185  46.187006      2.536185
#
#   lat.notified long.origin.rand  lat.origin.rand  long.notified.rand  \
# 0    50.639814         6.185632        50.209710            4.178676
# 1    45.679552       -94.358596        33.316786         -112.120696
# 2    46.187006         5.772482        49.475143            6.806947
# 3    46.187006         3.036312        47.324240           -3.723047
# 4    46.187006         7.161731        43.821795            5.146405
#
#   lat.notified.rand
# 0         50.869108
# 1         47.499206
# 2         48.674944
# 3         48.392345
# 4         49.066155
#
# [5 rows x 30 columns]

# %%
raw_df = pd.read_csv('../data/tidy/governance_data_world_bank.csv', encoding="utf-8")
raw_df.head()
# Out:
#        Country                 Indicator              Measure Names  Year  \
# 0  Afghanistan  Voice and Accountability             Standard Error  2018
# 1  Afghanistan  Voice and Accountability            Percentile Rank  2018
# 2  Afghanistan  Voice and Accountability  Governance (-2.5 to +2.5)  2018
# 3  Afghanistan  Voice and Accountability          Number of Sources  2018
# 4      Albania  Voice and Accountability             Standard Error  2018
#
#    Measure Values
# 0        0.134822
# 1       20.689655
# 2       -0.994720
# 3       10.000000
# 4        0.128046

# %%
df = pd.DataFrame(columns=['Country', 'Indicator', 'Governance (-2.5 to +2.5)', 'Number of Sources', 'Standard Error', 'Percentile Rank'])
grouped = raw_df.groupby(by=['Country', 'Indicator'])
for a, b in grouped:
    row = list(a)
    row.append(b.loc[b['Measure Names'] == processed.columns[2]]['Measure Values'].values[0])
    row.append(b.loc[b['Measure Names'] == processed.columns[3]]['Measure Values'].values[0])
    row.append(b.loc[b['Measure Names'] == processed.columns[4]]['Measure Values'].values[0])
    row.append(b.loc[b['Measure Names'] == processed.columns[5]]['Measure Values'].values[0])
    df.loc[len(df)] = row
df['recall_count'] = np.nan
recalls = food_haz.loc[food_haz.alert_type == 'recall']
countries_recall = recalls.groupby('origin_country')
for country, data in countries_recall:
    recall_count = len(data.ID.unique())
    df['recall_count'].loc[df.Country == country] = recall_count
df.head()
# Out:
#        Country                                          Indicator  \
# 0  Afghanistan                              Control of Corruption
# 1  Afghanistan                           Government Effectiveness
# 2  Afghanistan  Political Stability and Absence of Violence/Te...
# 3  Afghanistan                                 Regulatory Quality
# 4  Afghanistan                                        Rule of Law
#
#    Governance (-2.5 to +2.5)  Number of Sources  Standard Error  \
# 0                  -1.496648               10.0        0.157296
# 1                  -1.457285                8.0        0.238051
# 2                  -2.746730                6.0        0.227786
# 3                  -1.132634                9.0        0.193525
# 4                  -1.668478               11.0        0.158724
#
#    Percentile Rank  recall_count
# 0         4.326923           NaN
# 1         7.692307           NaN
# 2         0.476190           NaN
# 3        10.576923           NaN
# 4         4.326923           NaN

# %%
indicator = 'Political Stability and Absence of Violence/Terrorism'
df_indicator = df.loc[df.Indicator == indicator]
indicator_recall = df_indicator[df_indicator.recall_count.notna()]

sns.scatterplot('Governance (-2.5 to +2.5)', 'recall_count', data=indicator_recall)
plt.xlabel(indicator)
plt.ylabel('Recalls')
plt.show()

# %%
indicator = 'Control of Corruption'

df_indicator = df.loc[df.Indicator == indicator]
indicator_recall = df_indicator[df_indicator.recall_count.notna()]

sns.scatterplot('Governance (-2.5 to +2.5)', 'recall_count', data=indicator_recall)
plt.xlabel(indicator)
plt.ylabel('Recalls')
plt.show()

# %%
indicator = 'Government Effectiveness'

df_indicator = df.loc[df.Indicator == indicator]
indicator_recall = df_indicator[df_indicator.recall_count.notna()]

sns.scatterplot('Governance (-2.5 to +2.5)', 'recall_count', data=indicator_recall)
plt.xlabel(indicator)
plt.ylabel('Recalls')
plt.show()

# %%
indicator = 'Regulatory Quality'

df_indicator = df.loc[df.Indicator == indicator]
indicator_recall = df_indicator[df_indicator.recall_count.notna()]

sns.scatterplot('Governance (-2.5 to +2.5)', 'recall_count', data=indicator_recall)
plt.xlabel(indicator)
plt.ylabel('Recalls')
plt.show()

# %%
indicator = 'Rule of Law'

df_indicator = df.loc[df.Indicator == indicator]
indicator_recall = df_indicator[df_indicator.recall_count.notna()]

sns.scatterplot('Governance (-2.5 to +2.5)', 'recall_count', data=indicator_recall)
plt.xlabel(indicator)
plt.ylabel('Recalls')
plt.show()

# %%
indicator = 'Voice and Accountability'

df_indicator = df.loc[df.Indicator == indicator]
indicator_recall = df_indicator[df_indicator.recall_count.notna()]

sns.scatterplot('Governance (-2.5 to +2.5)', 'recall_count', data=indicator_recall)
plt.xlabel(indicator)
plt.ylabel('Recalls')
plt.show()
