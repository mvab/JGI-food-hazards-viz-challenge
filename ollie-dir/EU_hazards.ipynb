# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
food_haz = pd.read_csv('../data/tidy/food_hazards_data_all.csv')
food_haz.head()
# Out:
#        ID  ID_incident date_published  \
# 0  218195       218195     2020-05-20
# 1  218196       218196     2020-05-20
# 2  218198       218198     2020-05-20
# 3  218199       218199     2020-05-20
# 4  218201       218201     2020-05-20
#
#                                data_source                data_source_name  \
# 0                  AFSCA Recalls (Belgium)                   AFSCA Recalls
# 1             Food Poisoning Bulletin (US)         Food Poisoning Bulletin
# 2  Product Recalls Website: Oulah (France)  Product Recalls Website: Oulah
# 3  Product Recalls Website: Oulah (France)  Product Recalls Website: Oulah
# 4  Product Recalls Website: Oulah (France)  Product Recalls Website: Oulah
#
#   data_source_country source_type alert_type  \
# 0             Belgium    Official    warning
# 1                 USA      Others   outbreak
# 2              France      Others     recall
# 3              France      Others     recall
# 4              France      Others     recall
#
#                                     raw_text_product  \
# 0  Allergens not listed on the label are almonds ...
# 1  Backyard Poultry Salmonella Outbreak Sickens 9...
# 2  Recall product : Terrine of guinea Fowl with g...
# 3  Recall product : Chiffonnade of ham cooked abo...
# 4      Recall product : peas & carrots brand DANIVAL
#
#                               product_categoty  ...  \
# 0                 nuts; nut products and seeds  ...
# 1       poultry meat and poultry meat products  ...
# 2                        fruits and vegetables  ...
# 3  meat and meat products (other than poultry)  ...
# 4                        fruits and vegetables  ...
#
#       date_published_fulltime alert_type_large long.origin lat.origin  \
# 0  2020-05-20 00:00:00 +00:00            alert    4.640646  50.639814
# 1  2020-05-20 00:00:00 +00:00            alert -112.461671  45.679552
# 2  2020-05-20 00:00:00 +00:00           recall    2.536185  46.187006
# 3  2020-05-20 00:00:00 +00:00           recall    2.536185  46.187006
# 4  2020-05-20 00:00:00 +00:00           recall    2.536185  46.187006
#
#   long.notified lat.notified long.origin.rand lat.origin.rand  \
# 0      4.640646    50.639814         4.652461       50.237388
# 1   -112.461671    45.679552       -95.516062       41.371988
# 2      2.536185    46.187006         0.172046       46.993052
# 3      2.536185    46.187006         1.843695       47.431894
# 4      2.536185    46.187006        -0.219988       44.499951
#
#   long.notified.rand  lat.notified.rand
# 0           4.767685          50.180495
# 1        -143.239688          67.398089
# 2           6.198627          46.126786
# 3           3.507758          46.954008
# 4          -0.997451          48.812467
#
# [5 rows x 34 columns]

# %%
food_haz.product_categoty.unique()
fruitveg = food_haz.loc[food_haz.product_categoty == 'fruits and vegetables']
fruitveg.head()
# Out:
#         ID  ID_incident date_published  \
# 2   218198       218198     2020-05-20
# 4   218201       218201     2020-05-20
# 9   218180       218180     2020-05-19
# 20  218131       218131     2020-05-15
# 38  218103       218103     2020-05-15
#
#                                 data_source                data_source_name  \
# 2   Product Recalls Website: Oulah (France)  Product Recalls Website: Oulah
# 4   Product Recalls Website: Oulah (France)  Product Recalls Website: Oulah
# 9                   AFSCA Recalls (Belgium)                   AFSCA Recalls
# 20                  AFSCA Recalls (Belgium)                   AFSCA Recalls
# 38            Australia Food Agency Recalls   Australia Food Agency Recalls
#
#    data_source_country source_type alert_type  \
# 2               France      Others     recall
# 4               France      Others     recall
# 9              Belgium    Official     recall
# 20             Belgium    Official     recall
# 38           Australia    Official     recall
#
#                                      raw_text_product       product_categoty  \
# 2   Recall product : Terrine of guinea Fowl with g...  fruits and vegetables
# 4       Recall product : peas & carrots brand DANIVAL  fruits and vegetables
# 9         possible presence of listeria monocytogenes  fruits and vegetables
# 20  possible presence of salmonella\n\n\n\ndelhaiz...  fruits and vegetables
# 38  ALDI PICK'D Cloudy Apple Juice 2L has been rec...  fruits and vegetables
#
#     ...     date_published_fulltime alert_type_large long.origin lat.origin  \
# 2   ...  2020-05-20 00:00:00 +00:00           recall    2.536185  46.187006
# 4   ...  2020-05-20 00:00:00 +00:00           recall    2.536185  46.187006
# 9   ...  2020-05-19 00:00:00 +00:00           recall    4.640646  50.639814
# 20  ...  2020-05-15 00:00:00 +00:00           recall    4.640646  50.639814
# 38  ...  2020-05-15 00:00:00 +00:00           recall  134.490999 -25.732887
#
#    long.notified lat.notified long.origin.rand lat.origin.rand  \
# 2       2.536185    46.187006         0.172046       46.993052
# 4       2.536185    46.187006        -0.219988       44.499951
# 9       4.640646    50.639814         4.921381       51.413572
# 20      4.640646    50.639814         4.638144       50.521592
# 38    134.490999   -25.732887       150.195535      -30.343139
#
#    long.notified.rand  lat.notified.rand
# 2            6.198627          46.126786
# 4           -0.997451          48.812467
# 9            4.955962          51.472034
# 20           5.851020          50.704237
# 38         147.201749         -36.108048
#
# [5 rows x 34 columns]

# %%
[x for x in fruitveg.raw_text_product if 'potato' in x]
# Out:
# ['soya; wheat and celery undeclared on chilled celeriac puree labelled as mashed potatoes from Belgium',
#  'Listeria monocytogenes (presence /100g) in frozen potato slices from Belgium',
#  'Dried sweet potato from China imported by OrientDeli AS; withdrawn from the market',
#  'wheat undeclared on frozen potato waffles from Belgium',
#  'sulphite and wheat undeclared on pasta salad with peppers and fennel incorrectly labelled as potato salad with spring onion and french cream from Germany',
#  'undeclared soya and wheat in sweet potato fries from the United Kingdom',
#  'undeclared gluten in frozen mashed potatoes mistakenly mixed with potato croquettes from Belgium',
#  'sulphite (135 mg/kg - ppm) undeclared in roasted potatoes with bacon from Germany',
#  'presence of gluten (31.6 mg/kg - ppm) in gluten-free cream preparation with potatoes and leeks from Italy',
#  'undeclared gluten and egg in frozen potato croquettes from Belgium',
#  'high content of acrylamide (2478;8 Âµg/kg - ppb) in potato crisps from Belgium',
#  'iglo sweet potato Loafs 270g',
#  'high content of acrylamide (1300 Âµg/kg - ppb) in sweet potato chips from the United States',
#  'metal pieces (+/- 1 cm) in frozen potato croquettes from Belgium',
#  'plastic fragments in potato flakes from Germany',
#  'foreign body (metal) in sliced potatoes and roasted potatoes from Germany',
#  'glass fragments in frozen mashed potatoes from Belgium',
#  'pieces of wood in organic potato chips from the Netherlands',
#  'plastic fragments in organic lentil pot with potatoes from Germany',
#  'metal pieces in potato dough and potato dumpling from Germany',
#  'Frozen food served after heating(other than those heated immediately before freezing):Diced potato - violation of compositional standard (E.coli positive)',
#  'Potato sticks: BATATA PALHA TRADICIONAL STIVAL - violation of standard of use (sodium hydrosulfite (as SO2) 0.12 g/kg detection(use of sodium hydrosulfite in other than target food(used for potato of the material)))',
#  'Sulfites not declared in sweet potato powder from China; via the netherlands (Ref. 2019/057)',
#  'fosthiazate (0.062 mg/kg - ppm) in potatoes from Cyprus',
#  'too high content of sulphite (80 mg/kg - ppm) in dried sweet potato from China; via the Netherlands',
#  'thiabendazole (0.77 mg/kg - ppm) and flonicamid (0.25 mg/kg - ppm) in potatoes from France',
#  'fosthiazate (0.0665 mg/kg - ppm) in potatoes from Cyprus; packaged in Belgium',
#  'unauthorised use of colour E 104 - quinoline yellow and of colour E 110 - Sunset Yellow FCF in potato crisps from the United States; via the United Kingdom',
#  'fosthiazate (0.057 mg/kg - ppm) in potatoes from Cyprus',
#  'unauthorised use of colour E 102 - tartrazine and of colour E 110 - Sunset Yellow FCF in plantain; potato and cassava flour from Ghana']
